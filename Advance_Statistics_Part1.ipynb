# %% [markdown]
# # Advance Statistics Part1

# %% [markdown]
# 1. What is a random variable in probability theory?
#   - A random variable in probability theory is a variable whose possible values are numerical outcomes of a random process.
#
# 2. What are the types of random variables?
#   - Discrete Random Variables: These take on a finite or countable number of distinct values.
#   - Continuous Random Variables: These can take on an infinite number of values within a given range.
#
# 3. What is the difference between discrete and continuous distributions?
#   - Discrete Distributions: Deal with countable outcomes (finite or countably infinite values). Used when data consists of separate, distinct values (e.g., number of defective items in a batch).
#   - Continuous Distributions: Deal with uncountable outcomes (infinite values within a range)
#
# 4. What are probability distribution functions (PDF)?
#   - A Probability Distribution Function (PDF) describes the likelihood of different outcomes for a random variable.
#
# 5.  How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
#   - Probability Density Function (PDF): Represents the probability of a random variable taking a specific value or falling within a small range.
#   - Cumulative Distribution Function (CDF): Represents the probability that a random variable will be less than or equal to a given value.
#
# 6. What is a discrete uniform distribution?
#   - A discrete uniform distribution is a probability distribution where all possible outcomes have equal probability of occurring.
#
# 7. What are the key properties of a Bernoulli distribution?
#   - Binary Outcomes:
#   - Variance:
#
# 8. What is the binomial distribution, and how is it used in probability?
#   - The binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent Bernoulli trials, each with the same probability of success.
#
# 9. What is the Poisson distribution and where is it applied?
#   - The Poisson distribution is a discrete probability distribution used to model the number of events occurring in a fixed interval of time or space, assuming that these events happen independently and at a constant average rate.
#   - Applications:
#     - Queueing systems: Predicting customer arrivals at a store or calls to a call center.
#     - Biology: Estimating the number of mutations in DNA strands.
#
# 10. What is a continuous uniform distribution?
#   - A continuous uniform distribution is a probability distribution where every value within a specified range is equally likely to occur. It is often used when there is no preference or bias toward any particular outcome.
#
# 11. What are the characteristics of a normal distribution?
#   - A normal distribution, also known as the Gaussian distribution, is one of the most important probability distributions in statistics and data analysis.
#
# 12. What is the standard normal distribution, and why is it important?
#   - The standard normal distribution is a special case of the normal distribution where the mean (𝜇) is 0, and the standard deviation (𝜎) is 1.
#   - Why is it Important?
#     - Simplifies Probability Calculations: Since tables exist for the standard normal distribution, probabilities for any normal distribution can be quickly found using Z-scores.
#     - Comparison of Different Normal Distributions: Converts different normal distributions into a common scale.
#
# 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#   - The Central Limit Theorem (CLT) is one of the most fundamental concepts in statistics.
#   - Why is CLT Critical in Statistics?
#     - Basis for Many Statistical Methods: CLT enables hypothesis testing, confidence intervals, and other inferential techniques.
#     - Justifies Sampling: Explains why data from a sample can be used to infer conclusions about an entire population.
#
# 14. How does the Central Limit Theorem relate to the normal distribution?
#   - Relation to the Normal Distribution:
#   - Sample Means Follow a Normal Distribution: Even if the original population distribution is not normal, the distribution of sample means will become approximately normal as the sample size increases.
#   - Foundation for Normal Approximation: Many real-world data sets follow a normal distribution because they result from the aggregation of many independent random influences—just like CLT predicts.
#
# 15. What is the application of Z statistics in hypothesis testing?
#   - Z-statistics play a crucial role in hypothesis testing, particularly when dealing with population means and proportions.
#
# 16.  How do you calculate a Z-score, and what does it represent?
#   - A Z-score, also known as a standard score, tells you how far a particular data point is from the mean of a dataset, measured in terms of standard deviations.
#
# 17. What are point estimates and interval estimates in statistics?
#   - Point Estimate: A single value used to approximate an unknown population parameter.
#   - Interval Estimate: Provides a range within which the true population parameter is likely to fall, often with an associated confidence level.
#
# 18. What is the significance of confidence intervals in statistical analysis?
#   - Confidence intervals are incredibly important in statistical analysis because they provide a measure of uncertainty and reliability in estimating population parameters.
#
# 19. What is the relationship between a Z-score and a confidence interval?
#   - Z-Scores Quantify Position in a Distribution: A Z-score represents how far a particular data point is from the mean, measured in standard deviations.
#   - Confidence Intervals Use Z-Scores to Define Ranges: Confidence intervals estimate where a population parameter (like the mean) is likely to fall.
#
# 20. How are Z-scores used to compare different distributions?
#   - Z-scores are incredibly useful for comparing different distributions, even when they have different means and standard deviations.
#
# 21. What are the assumptions for applying the Central Limit Theorem?
#   - The Central Limit Theorem (CLT) is a fundamental principle in statistics, stating that the distribution of the sample mean approaches a normal distribution as the sample size increases—regardless of the original population’s shape.
#   - Key Assumptions for the Central Limit Theorem
#      - Independence of Samples
#      - Random Sampling
#
# 22. What is the concept of expected value in a probability distribution?
#   - Expected value (EV) is a fundamental concept in probability that represents the long-term average outcome of a random variable.
#
# 23.  How does a probability distribution relate to the expected outcome of a random variable?
#   - A probability distribution defines how likely different outcomes of a random variable are, and the expected value (or expectation) gives the weighted average of those possible outcomes.

# %%
# PRACTICAL

# %%
#Q.1 Write a Python program to generate a random variable and display its value.
# Generate a random integer between 1 and 100
random_variable = random.randint(1, 100)

# Display the generated value
print("Generated Random Variable:", random_variable)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-96c1c704a3a0> in <cell line: 0>()
#       1 #Q.1 Write a Python program to generate a random variable and display its value.
#       2 # Generate a random integer between 1 and 100
# ----> 3 random_variable = random.randint(1, 100)
#       4
#       5 # Display the generated value
#
# NameError: name 'random' is not defined

# %%
#2.Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).
import numpy as np

# %%
#3.Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.
def pdf_bernoulli(p, x):
    if x == 0:
        return 1 - p
    elif x == 1:
        return p
    else:
        return 0

# %%
#4.Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 10  # Number of trials
p = 0.5  # Probability of success
size = 1000  # Number of simulations

# Generate binomial distribution samples
data = np.random.binomial(n, p, size)

# Plot histogram
plt.hist(data, bins=range(n+2), density=True, edgecolor='black', alpha=0.7)

# Labels and title
plt.xlabel('Number of successes')
plt.ylabel('Probability')
plt.title(f'Binomial Distribution (n={n}, p={p})')

# Show plot
plt.show()

# %%
#5.Create a Poisson distribution and visualize it using Python.
import numpy as np
import matplotlib.pyplot as plt

# Parameters
lambda_ = 4  # Mean number of occurrences
size = 1000  # Number of simulations

# %%
#6.Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.
import numpy as np
import matplotlib.pyplot as plt

# Parameters
low = 1  # Minimum value
high = 10  # Maximum value
size = 1000  # Number of samples

# Generate discrete uniform distribution samples
data = np.random.randint(low, high + 1, size)

# Calculate CDF
values, counts = np.unique(data, return_counts=True)
cumulative_counts = np.cumsum(counts) / size  # Normalize for probability

# Plot CDF
plt.step(values, cumulative_counts, where="post", linestyle="--", marker="o", color="blue", label="CDF")
plt.xlabel("Value")
plt.ylabel("Cumulative Probability")
plt.title(f"CDF of Discrete Uniform Distribution ({low}-{high})")
plt.legend()
plt.grid()

# Show plot
plt.show()

# %%
#7.Generate a continuous uniform distribution using NumPy and visualize it.
import numpy as np
import matplotlib.pyplot as plt

# Parameters
low = 0  # Minimum value
high = 1  # Maximum value
size = 1000  # Number of samples

# Generate continuous uniform distribution samples
data = np.random.uniform(low, high, size)

# Plot histogram
plt.hist(data, bins=30, density=True, edgecolor='black', alpha=0.7)

# Labels and title
plt.xlabel("Value")
plt.ylabel("Density")
plt.title(f"Continuous Uniform Distribution ({low}, {high})")

# Show plot
plt.show()

# %%
#8.Simulate data from a normal distribution and plot its histogram.
import numpy as np
import matplotlib.pyplot as plt

# Parameters
mean = 0  # Mean of the distribution
std_dev = 1  # Standard deviation
size = 1000  # Number of samples

# Generate normal distribution samples
data = np.random.normal(mean, std_dev, size)

# Plot histogram
plt.hist(data, bins=30, density=True, edgecolor='black', alpha=0.7)

# Labels and title
plt.xlabel("Value")
plt.ylabel("Density")
plt.title(f"Normal Distribution (mean={mean}, std dev={std_dev})")

# Show plot
plt.show()

# %%
#9. Write a Python function to calculate Z-scores from a dataset and plot them.
import numpy as np
import matplotlib.pyplot as plt

def calculate_z_scores(data):
    """Calculate Z-scores for a dataset."""
    mean = np.mean(data)
    std_dev = np.std(data)
    return (data - mean) / std_dev

# Sample dataset
np.random.seed(42)  # For reproducibility
data = np.random.normal(loc=50, scale=10, size=1000)  # Generating a normal distribution

# Compute Z-scores
z_scores = calculate_z_scores(data)

# Plot histogram of Z-scores
plt.hist(z_scores, bins=30, density=True, edgecolor='black', alpha=0.7)

# Labels and title
plt.xlabel("Z-score")
plt.ylabel("Density")
plt.title("Z-score Distribution")

# Show plot
plt.show()

# %%
#10.Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.
import numpy as np
import matplotlib.pyplot as plt

# Generate non-normal population data (exponential distribution)
population = np.random.exponential(scale=2, size=10000)

# Sample size and number of samples
sample_size = 30
num_samples = 1000

# Compute sample means
sample_means = [np.mean(np.random.choice(population, sample_size)) for _ in range(num_samples)]

# Plot histogram of sample means
plt.hist(sample_means, bins=30, density=True, edgecolor='black', alpha=0.7)

# Labels and title
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.title("Central Limit Theorem Demonstration (Exponential Distribution)")
# Out:
# Text(0.5, 1.0, 'Central Limit Theorem Demonstration (Exponential Distribution)')

# %%
#15.Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.
import numpy as np
import matplotlib.pyplot as plt

# Generate population data from a normal distribution
population_mean = 50
population_std_dev = 15
population_size = 10000

population = np.random.normal(population_mean, population_std_dev, population_size)

# Sampling parameters
sample_size = 30  # Size of each sample
num_samples = 1000  # Number of samples

# Compute sample means
sample_means = [np.mean(np.random.choice(population, sample_size)) for _ in range(num_samples)]

# Plot histogram of sample means
plt.hist(sample_means, bins=30, density=True, edgecolor='black', alpha=0.7)

# Labels and title
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.title("Verification of Central Limit Theorem (Normal Distribution)")

# Show plot
plt.show()

# %%
#16.Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

def plot_standard_normal():
    """Plots the standard normal distribution (mean=0, std=1)."""
    x = np.linspace(-4, 4, 1000)  # Generate values from -4 to 4
    y = stats.norm.pdf(x, loc=0, scale=1)  # Calculate probability density function

    # Plot the curve
    plt.plot(x, y, color="blue", label="Standard Normal Distribution")
    plt.xlabel("Value")
    plt.ylabel("Probability Density")
    plt.title("Standard Normal Distribution (mean=0, std=1)")
    plt.legend()
    plt.grid()

    # Show plot
    plt.show()

# Call function to plot
plot_standard_normal()

# %%
#17. Generate random variables and calculate their corresponding probabilities using the binomial distribution.
import numpy as np
import scipy.stats as stats

# Parameters
n = 10  # Number of trials
p = 0.5  # Probability of success
size = 10  # Number of random variables

# Generate random binomial variables
random_vars = np.random.binomial(n, p, size)

# Calculate probabilities using the binomial probability mass function (PMF)
probabilities = stats.binom.pmf(random_vars, n, p)

# Display results
for i in range(size):
    print(f"Random variable: {random_vars[i]}, Probability: {probabilities[i]:.4f}")
# Out:
# Random variable: 3, Probability: 0.1172
# Random variable: 5, Probability: 0.2461
# Random variable: 5, Probability: 0.2461
# Random variable: 4, Probability: 0.2051
# Random variable: 6, Probability: 0.2051
# Random variable: 4, Probability: 0.2051
# Random variable: 4, Probability: 0.2051
# Random variable: 3, Probability: 0.1172
# Random variable: 6, Probability: 0.2051
# Random variable: 4, Probability: 0.2051

# %%
#18.Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.
import scipy.stats as stats

def calculate_z_score(data_point, mean, std_dev):
    """Calculate the Z-score of a given data point."""
    return (data_point - mean) / std_dev

# Example usage
data_point = 50
mean = 45
std_dev = 5

z_score = calculate_z_score(data_point, mean, std_dev)
print(f"Z-score: {z_score}")

# Compare to standard normal distribution
p_value = stats.norm.sf(abs(z_score))  # One-tailed probability
print(f"Probability of observing a value more extreme: {p_value:.4f}")
# Out:
# Z-score: 1.0
# Probability of observing a value more extreme: 0.1587

# %%
#19.Implement hypothesis testing using Z-statistics for a sample dataset.
import numpy as np
import scipy.stats as stats

# Sample dataset
sample_data = np.array([50, 52, 48, 53, 49, 51, 47, 54, 50, 49])
sample_size = len(sample_data)
sample_mean = np.mean(sample_data)
sample_std_dev = np.std(sample_data, ddof=1)  # Sample standard deviation

# %%
#20. Create a confidence interval for a dataset using Python and interpret the result.
import numpy as np
import scipy.stats as stats

# Sample dataset
data = np.array([50, 52, 48, 53, 49, 51, 47, 54, 50, 49])

# Sample statistics
sample_mean = np.mean(data)
sample_std_dev = np.std(data, ddof=1)  # Using Bessel's correction
sample_size = len(data)

# %%
#21. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.
import numpy as np
import scipy.stats as stats

# Generate synthetic data from a normal distribution
np.random.seed(42)  # For reproducibility
mean_population = 50
std_dev_population = 5
sample_size = 30

sample_data = np.random.normal(mean_population, std_dev_population, sample_size)

# Calculate sample statistics
sample_mean = np.mean(sample_data)
sample_std_dev = np.std(sample_data, ddof=1)  # Using Bessel's correction

# Confidence level
confidence_level = 0.95  # 95% confidence interval
alpha = 1 - confidence_level
t_critical = stats.t.ppf(1 - alpha/2, df=sample_size - 1)  # Two-tailed t-score

# Margin of error
margin_error = t_critical * (sample_std_dev / np.sqrt(sample_size))

# Confidence interval
lower_bound = sample_mean - margin_error
upper_bound = sample_mean + margin_error

# Output results
print(f"Generated Sample Mean: {sample_mean:.2f}")
print(f"Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")

# Interpretation
print("\nInterpretation:")
print(f"We are {confidence_level * 100}% confident that the true population mean lies between {lower_bound:.2f} and {upper_bound:.2f}.")
# Out:
# Generated Sample Mean: 49.06
# Confidence Interval: (47.38, 50.74)
#
# Interpretation:
# We are 95.0% confident that the true population mean lies between 47.38 and 50.74.

# %%
#22.Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Define parameters for the normal distribution
mean = 0  # Mean (mu)
std_dev = 1  # Standard deviation (sigma)

# Generate x values (range of values around the mean)
x_values = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)

# Compute the PDF
pdf_values = stats.norm.pdf(x_values, mean, std_dev)

# Plot the PDF
plt.figure(figsize=(8, 5))
plt.plot(x_values, pdf_values, label=f"Normal Distribution (μ={mean}, σ={std_dev})", color='blue')
plt.xlabel("X-values")
plt.ylabel("Probability Density")
plt.title("Probability Density Function (PDF) of Normal Distribution")
plt.legend()
plt.grid()

# Show the plot
plt.show()

# %%
#23. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Define parameters for the Poisson distribution
lambda_poisson = 5  # Average rate (mean)

# Generate x values (possible number of occurrences)
x_values = np.arange(0, 20)  # Values from 0 to 19

# Compute the CDF
cdf_values = stats.poisson.cdf(x_values, lambda_poisson)

# Plot the CDF
plt.figure(figsize=(8, 5))
plt.plot(x_values, cdf_values, marker='o', linestyle='-', color='red', label=f"Poisson CDF (λ={lambda_poisson})")
plt.xlabel("Number of occurrences")
plt.ylabel("Cumulative Probability")
plt.title("Cumulative Distribution Function (CDF) of Poisson Distribution")
plt.legend()
plt.grid()

# Show the plot
plt.show()

# Interpretation: Probability of observing a value <= 5
probability = stats.poisson.cdf(5, lambda_poisson)
print(f"Probability of observing 5 or fewer occurrences: {probability:.4f}")
# Out:
# Probability of observing 5 or fewer occurrences: 0.6160

# %%
#24.Simulate a random variable using a continuous uniform distribution and calculate its expected value.
import numpy as np

# Define parameters for the uniform distribution
a, b = 10, 50  # Lower and upper bounds of the distribution

# Simulate a random variable from the uniform distribution
sample_size = 1000
random_samples = np.random.uniform(a, b, sample_size)

# Calculate expected value (theoretical mean)
expected_value = (a + b) / 2

# Calculate sample mean (empirical mean)
sample_mean = np.mean(random_samples)

# Output results
print(f"Theoretical Expected Value: {expected_value:.2f}")
print(f"Empirical Sample Mean: {sample_mean:.2f}")
# Out:
# Theoretical Expected Value: 30.00
# Empirical Sample Mean: 29.79

# %%
#25.Write a Python program to compare the standard deviations of two datasets and visualize the difference.
import numpy as np
import matplotlib.pyplot as plt

# Generate two datasets
np.random.seed(42)  # For reproducibility
dataset1 = np.random.normal(loc=50, scale=5, size=1000)  # Mean=50, Std Dev=5
dataset2 = np.random.normal(loc=50, scale=10, size=1000) # Mean=50, Std Dev=10

# Calculate standard deviations
std_dev1 = np.std(dataset1, ddof=1)
std_dev2 = np.std(dataset2, ddof=1)

# Print standard deviations
print(f"Standard Deviation of Dataset 1: {std_dev1:.2f}")
print(f"Standard Deviation of Dataset 2: {std_dev2:.2f}")

# Visualization
# Out:
# Standard Deviation of Dataset 1: 4.90
# Standard Deviation of Dataset 2: 9.97

# %%
#26.Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.
import numpy as np

# Generate data from a normal distribution
np.random.seed(42)  # For reproducibility
mean_population = 50
std_dev_population = 10
sample_size = 100

sample_data = np.random.normal(mean_population, std_dev_population, sample_size)

# Calculate range
data_range = np.max(sample_data) - np.min(sample_data)

# Calculate interquartile range (IQR)
q1 = np.percentile(sample_data, 25)
q3 = np.percentile(sample_data, 75)
iqr = q3 - q1

# Output results
print(f"Range of dataset: {data_range:.2f}")
print(f"Interquartile Range (IQR): {iqr:.2f}")
# Out:
# Range of dataset: 44.72
# Interquartile Range (IQR): 10.07

# %%
#27. Implement Z-score normalization on a dataset and visualize its transformation.
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Generate a sample dataset
np.random.seed(42)  # For reproducibility
data = np.random.normal(loc=50, scale=15, size=1000)  # Mean=50, Std Dev=15

# Z-score normalization
mean_data = np.mean(data)
std_dev_data = np.std(data, ddof=1)
z_normalized_data = (data - mean_data) / std_dev_data

# Visualization
plt.figure(figsize=(10, 5))

# Original dataset histogram
plt.subplot(1, 2, 1)
plt.hist(data, bins=30, alpha=0.7, color='blue', label="Original Data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Original Dataset")
plt.legend()
plt.grid()

# Z-score normalized dataset histogram
plt.subplot(1, 2, 2)
plt.hist(z_normalized_data, bins=30, alpha=0.7, color='red', label="Z-score Normalized Data")
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.title("Z-score Normalized Dataset")
plt.legend()
plt.grid()

# Show plots
plt.tight_layout()
plt.show()

# Print sample statistics
print(f"Original Mean: {mean_data:.2f}, Original Std Dev: {std_dev_data:.2f}")
print(f"Normalized Mean: {np.mean(z_normalized_data):.2f}, Normalized Std Dev: {np.std(z_normalized_data, ddof=1):.2f}")
# Out:
# Original Mean: 50.29, Original Std Dev: 14.69
# Normalized Mean: 0.00, Normalized Std Dev: 1.00

# %%
#28.Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.
import numpy as np
import scipy.stats as stats

def calculate_skewness_kurtosis(data):
    """Calculate the skewness and kurtosis of a dataset."""
    skewness = stats.skew(data)
    kurtosis = stats.kurtosis(data)  # Excess kurtosis (subtracts 3)
    return skewness, kurtosis

# Generate synthetic data from a normal distribution
np.random.seed(42)  # For reproducibility
normal_data = np.random.normal(loc=50, scale=10, size=1000)

# Compute skewness and kurtosis
skewness_value, kurtosis_value = calculate_skewness_kurtosis(normal_data)

# Output results
print(f"Skewness: {skewness_value:.4f}")
print(f"Kurtosis (Excess): {kurtosis_value:.4f}")
# Out:
# Skewness: 0.1168
# Kurtosis (Excess): 0.0662
